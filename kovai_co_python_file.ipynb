# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt




df = pd.read_csv("/content/drive/MyDrive/Daily_Public_Transport_Passenger_Journeys_by_Service_Type_20250526.csv")


missing_counts = df.isnull().sum()


def count_outliers_iqr(series):
    if not np.issubdtype(series.dtype, np.number):
        return 0
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return ((series < lower) | (series > upper)).sum()

outlier_counts = df.apply(count_outliers_iqr)


summary_df = pd.DataFrame({
    'Missing Values': missing_counts,
    'Outliers': outlier_counts
})


print("📊 Missing & Outliers Summary:")
print(summary_df)


plt.figure(figsize=(12, 6))


plt.plot(summary_df.index, summary_df['Missing Values'], marker='o', label='Missing Values', color='red')


plt.plot(summary_df.index, summary_df['Outliers'], marker='s', label='Outliers', color='blue')


plt.title('Missing Values and Outliers per Column', fontsize=14)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 Missing & Outliers Summary:
#               Missing Values  Outliers
# Date                       0         0
# Local Route                0         0
# Light Rail                 0         0
# Peak Service               0         1
# Rapid Route                0         0
# School                     0         0
# Other                     20         9

# %%
# !pip install pmdarima
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.3 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y numpy pmdarima
# !pip install numpy==1.23.5
# !pip install pmdarima --no-binary :all:
# Out:
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# WARNING: Skipping pmdarima as it is not installed.
# ...
#   Using cached numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Using cached numpy-1.23.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# xarray 2025.3.1 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.23.5 which is incompatible.
# bigframes 2.4.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !pip install pmdarima

import pandas as pd
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX


df = pd.read_csv("/content/drive/MyDrive/Daily_Public_Transport_Passenger_Journeys_by_Service_Type_20250526.csv")
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)


modes = ['Local Route', 'Light Rail', 'Peak Service', 'Rapid Route', 'School', 'Other']

for mode in modes:
    print(f"\n🔍 Forecasting: {mode}")


    series = df[mode].fillna(df[mode].mean())


    plt.figure(figsize=(12, 4))
    plt.plot(series, label=f"{mode} - Observed")
    plt.title(f"{mode} - Daily Passenger Journeys")
    plt.xlabel("Date")
    plt.ylabel("Passenger Count")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


    stepwise_model = auto_arima(series,
                                 seasonal=True,
                                 m=7,
                                 start_p=0, start_q=0,
                                 max_p=3, max_q=3,
                                 start_P=0, start_Q=0,
                                 max_P=2, max_Q=2,
                                 d=None, D=None,
                                 trace=False,
                                 error_action='ignore',
                                 suppress_warnings=True,
                                 stepwise=True)

    print("✅ Best SARIMA Order:", stepwise_model.order)
    print("✅ Best Seasonal Order:", stepwise_model.seasonal_order)


    model = SARIMAX(series,
                    order=stepwise_model.order,
                    seasonal_order=stepwise_model.seasonal_order,
                    enforce_stationarity=False,
                    enforce_invertibility=False)
    results = model.fit(disp=False)


    forecast = results.get_forecast(steps=14)
    forecast_ci = forecast.conf_int()


    ax = series.plot(label='Observed', figsize=(12, 5))
    forecast.predicted_mean.plot(ax=ax, label='Forecast', color='green')
    ax.fill_between(forecast_ci.index,
                    forecast_ci.iloc[:, 0],
                    forecast_ci.iloc[:, 1], color='lightgreen', alpha=0.3)
    plt.title(f"14-Day Forecast for {mode}")
    plt.xlabel('Date')
    plt.ylabel('Passenger Count')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# ...
# <ipython-input-5-a94e53006baa>:10: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])
# 🔍 Forecasting: Local Route
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

forecast_results = []

for mode in modes:
    series = df[mode].fillna(df[mode].mean())

    if len(series) >= 28:
        actual = series[-14:]
        predicted = results.get_prediction(start=actual.index[0], end=actual.index[-1]).predicted_mean
        rmse = np.sqrt(mean_squared_error(actual, predicted))
        mae = mean_absolute_error(actual, predicted)
        r2 = r2_score(actual, predicted)
        print(f"📊 Evaluation for {mode}")
        print(f"   - RMSE: {rmse:.2f}")
        print(f"   - MAE: {mae:.2f}")
        print(f"   - R² Score: {r2:.2f}")
    else:
        print(f"ℹ️ Not enough historical data for evaluation in {mode}")


    forecast_dates = pd.date_range(series.index[-1] + pd.Timedelta(days=1), periods=14)
    forecast_values = forecast.predicted_mean
    forecast_ci = forecast.conf_int()

    forecast_df = pd.DataFrame({
        'Date': forecast_dates,
        'Mode': mode,
        'Forecast': forecast_values.values,
        'Lower CI': forecast_ci.iloc[:, 0].values,
        'Upper CI': forecast_ci.iloc[:, 1].values
    })

    forecast_results.append(forecast_df)


all_forecasts = pd.concat(forecast_results)
all_forecasts.to_csv("Passenger_Journey_14Day_Forecast.csv", index=False)
print("\n📁 Forecasts saved as Passenger_Journey_14Day_Forecast.csv")
# Out:
# 📊 Evaluation for Local Route
#    - RMSE: 11533.22
#    - MAE: 9805.70
#    - R² Score: -2.61
# 📊 Evaluation for Light Rail
#    - RMSE: 8366.86
#    - MAE: 7446.13
#    - R² Score: -3.82
# 📊 Evaluation for Peak Service
#    - RMSE: 231.52
#    - MAE: 182.36
#    - R² Score: -1.29
# 📊 Evaluation for Rapid Route
#    - RMSE: 14595.55
#    - MAE: 12834.48
#    - R² Score: -3.41
# 📊 Evaluation for School
#    - RMSE: 2964.43
#    - MAE: 1784.45
#    - R² Score: -0.55
# 📊 Evaluation for Other
#    - RMSE: 45.60
#    - MAE: 33.30
#    - R² Score: -0.98
#
# 📁 Forecasts saved as Passenger_Journey_14Day_Forecast.csv
